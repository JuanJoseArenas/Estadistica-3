# %%
import pandas as pd
import numpy as np
import math
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Regresión**

# %% [markdown]
# **1. Realizar la exploración de los datos correlación, scatter plots, boxplots e
# histogramas:**

# %%
df_train_raw = pd.read_csv("training_pruebas.csv", low_memory=False)
df_train_raw
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                      CC          COLOMBIA           M           12/12/2000
# 1                      CC          COLOMBIA           M           21/07/2001
# 2                      CC          COLOMBIA           F           21/04/1997
# 3                      CC          COLOMBIA           F           20/07/1995
# 4                      CC          COLOMBIA           F           02/06/1978
# ...                   ...               ...         ...                  ...
# 111425                 CC          COLOMBIA           F           08/02/2001
# 111426                 CC          COLOMBIA           F           06/10/2000
# 111427                 CC          COLOMBIA           M           10/01/1965
# 111428                 CC          COLOMBIA           F           14/11/2001
# 111429                 CC          COLOMBIA           M           09/10/1998
#
#        ESTU_EXTERIOR  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0                 NO    20231   EK202310215107      ESTUDIANTE
# 1                 NO    20231   EK202310116775      ESTUDIANTE
# 2                 NO    20231   EK202310113020      ESTUDIANTE
# 3                 NO    20231   EK202310184031      ESTUDIANTE
# 4                 NO    20231   EK202310177032      ESTUDIANTE
# ...              ...      ...              ...             ...
# 111425            NO    20231   EK202310196332      ESTUDIANTE
# 111426            NO    20231   EK202310214172      ESTUDIANTE
# 111427            NO    20231   EK202310223689      ESTUDIANTE
# 111428            NO    20231   EK202310147254      ESTUDIANTE
# 111429            NO    20231   EK202310239919      ESTUDIANTE
#
#        ESTU_PAIS_RESIDE ESTU_DEPTO_RESIDE  ...  ESTU_PRIVADO_LIBERTAD  \
# 0              COLOMBIA         ATLANTICO  ...                      N
# 1              COLOMBIA            CALDAS  ...                      N
# 2              COLOMBIA            TOLIMA  ...                      N
# 3              COLOMBIA        LA GUAJIRA  ...                      N
# 4              COLOMBIA             VALLE  ...                      N
# ...                 ...               ...  ...                    ...
# 111425         COLOMBIA            BOYACA  ...                      N
# 111426         COLOMBIA             VALLE  ...                      N
# 111427         COLOMBIA             CESAR  ...                      N
# 111428         COLOMBIA         ATLANTICO  ...                      N
# 111429         COLOMBIA             VALLE  ...                      N
#
#        ESTU_COD_MCPIO_PRESENTACION  ESTU_MCPIO_PRESENTACION  \
# 0                             8001             BARRANQUILLA
# 1                            17444              MARQUETALIA
# 2                            73268                  ESPINAL
# 3                            44001                 RIOHACHA
# 4                            76001                     CALI
# ...                            ...                      ...
# 111425                       15238                  DUITAMA
# 111426                       76622               ROLDANILLO
# 111427                       20001               VALLEDUPAR
# 111428                        8001             BARRANQUILLA
# 111429                       76001                     CALI
#
#        ESTU_DEPTO_PRESENTACION ESTU_COD_DEPTO_PRESENTACION PUNT_GLOBAL  \
# 0                    ATLANTICO                           8         188
# 1                       CALDAS                          17         140
# 2                       TOLIMA                          73         140
# 3                   LA GUAJIRA                          44         111
# 4                        VALLE                          76         135
# ...                        ...                         ...         ...
# 111425                  BOYACA                          15         137
# 111426                   VALLE                          76         161
# 111427                   CESAR                          20         124
# 111428               ATLANTICO                           8         142
# 111429                   VALLE                          76         148
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_IES  \
# 0                 55.570156                 3.0            2
# 1                 38.105883                 1.0            2
# 2                 65.658631                 4.0            2
# 3                 49.260729                 2.0            2
# 4                 55.138843                 2.0            3
# ...                     ...                 ...          ...
# 111425                  NaN                 NaN            2
# 111426            63.619372                 4.0            3
# 111427            48.648902                 2.0            2
# 111428            52.877602                 2.0            4
# 111429            47.195704                 2.0            2
#
#        ESTU_ESTADOINVESTIGACION
# 0                      PUBLICAR
# 1                      PUBLICAR
# 2                      PUBLICAR
# 3                      PUBLICAR
# 4                      PUBLICAR
# ...                         ...
# 111425                 PUBLICAR
# 111426                 PUBLICAR
# 111427                 PUBLICAR
# 111428                 PUBLICAR
# 111429                 PUBLICAR
#
# [111430 rows x 78 columns]

# %%
df_nuevo = df_train['PUNT_GLOBAL']
df_nuevo_test = pd.DataFrame(columns=['ID'])
df_nuevo_test['ID'] = range(0, len(df_test))
dummies = pd.get_dummies(df_train['ESTU_GENERO'], drop_first=True)
dummies.columns = ['GENERO']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['PUNT_GLOBAL', 'GENERO']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_GENERO'], drop_first=True)
dummies_test.columns = ['GENERO']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#              PUNT_GLOBAL    GENERO
# PUNT_GLOBAL     1.000000 -0.074096
# GENERO         -0.074096  1.000000

# %%
plt.scatter(df_nuevo['GENERO'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre Genero y Puntaje Global')
plt.xlabel('GENERO (0 = Femenino, 1 = Masculino)')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['ESTU_EXTERIOR'], drop_first=True)
dummies.columns = ['ESTU_EXTERIOR']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['PUNT_GLOBAL', 'ESTU_EXTERIOR']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_EXTERIOR'], drop_first=True)
dummies_test.columns = ['ESTU_EXTERIOR']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#                PUNT_GLOBAL  ESTU_EXTERIOR
# PUNT_GLOBAL       1.000000       0.081207
# ESTU_EXTERIOR     0.081207       1.000000

# %%
plt.scatter(df_nuevo['ESTU_EXTERIOR'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre estudio exterior y Puntaje Global')
plt.xlabel('ESTU_EXTERIOR (0 = No estudios ext, 1 = Estudios ext)')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['ESTU_AREARESIDE'], drop_first=True)
dummies.columns = ['AREA_RESIDE']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['PUNT_GLOBAL', 'AREA_RESIDE']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_AREARESIDE'], drop_first=True)
dummies_test.columns = ['AREA_RESIDE']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#              PUNT_GLOBAL  AREA_RESIDE
# PUNT_GLOBAL     1.000000     0.129077
# AREA_RESIDE     0.129077     1.000000

# %%
plt.scatter(df_nuevo['AREA_RESIDE'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre area reside y Puntaje Global')
plt.xlabel('AREA RESIDE (0 = Area Rural, 1 = Cabecera Municipal)')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['ESTU_TITULOOBTENIDOBACHILLER'], drop_first=True)
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
df = pd.concat([df_train, dummies], axis=1)
print(df[dummies.columns].corrwith(df['PUNT_GLOBAL']))

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_TITULOOBTENIDOBACHILLER'], drop_first=True)
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
# Bachiller pedagógico o normalista   -0.004141
# Bachiller técnico                   -0.025083
# dtype: float64

# %%
plt.scatter(df_nuevo['Bachiller pedagógico o normalista'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre Bachiller pedagógico o normalista y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
plt.scatter(df_nuevo['Bachiller técnico'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre Bachiller técnico y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['ESTU_VALORMATRICULAUNIVERSIDAD'], drop_first=True)
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
df = pd.concat([df_train, dummies], axis=1)
print(df[dummies.columns].corrwith(df['PUNT_GLOBAL']))

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_VALORMATRICULAUNIVERSIDAD'], drop_first=True)
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
# Entre 2.5 millones y menos de 4 millones   -0.085131
# Entre 4 millones y menos de 5.5 millones    0.013439
# Entre 5.5 millones y menos de 7 millones    0.059240
# Entre 500 mil y menos de 1 millón           0.008578
# Menos de 500 mil                            0.033690
# Más de 7 millones                           0.244534
# No pagó matrícula                           0.006933
# dtype: float64

# %%
dummies = pd.get_dummies(df_train['FAMI_ESTRATOVIVIENDA'], drop_first=True)
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
df = pd.concat([df_train, dummies], axis=1)
print(df[dummies.columns].corrwith(df['PUNT_GLOBAL']))

## Data test

dummies_test = pd.get_dummies(df_test['FAMI_ESTRATOVIVIENDA'], drop_first=True)
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
# Estrato 2     -0.072688
# Estrato 3      0.076760
# Estrato 4      0.143866
# Estrato 5      0.112342
# Estrato 6      0.087452
# Sin Estrato   -0.037404
# dtype: float64

# %%
dummies = pd.get_dummies(df_train['FAMI_TIENEINTERNET'], drop_first=True)
dummies.columns = ['INTERNET']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['INTERNET', 'PUNT_GLOBAL']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['FAMI_TIENEINTERNET'], drop_first=True)
dummies_test.columns = ['INTERNET']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#              INTERNET  PUNT_GLOBAL
# INTERNET     1.000000     0.141491
# PUNT_GLOBAL  0.141491     1.000000

# %%
plt.scatter(df_nuevo['INTERNET'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre INTERNET y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['FAMI_TIENECOMPUTADOR'], drop_first=True)
dummies.columns = ['COMPUTADOR']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['COMPUTADOR', 'PUNT_GLOBAL']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['FAMI_TIENECOMPUTADOR'], drop_first=True)
dummies_test.columns = ['COMPUTADOR']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#              COMPUTADOR  PUNT_GLOBAL
# COMPUTADOR     1.000000     0.147503
# PUNT_GLOBAL    0.147503     1.000000

# %%
plt.scatter(df_nuevo['COMPUTADOR'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre COMPUTADOR y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['FAMI_TIENESERVICIOTV'], drop_first=True)
dummies.columns = ['SERVICIO_TV']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['SERVICIO_TV', 'PUNT_GLOBAL']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['FAMI_TIENESERVICIOTV'], drop_first=True)
dummies_test.columns = ['SERVICIO_TV']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#              SERVICIO_TV  PUNT_GLOBAL
# SERVICIO_TV     1.000000     0.040291
# PUNT_GLOBAL     0.040291     1.000000

# %%
plt.scatter(df_nuevo['SERVICIO_TV'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre SERVICIO_TV y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['FAMI_TIENECONSOLAVIDEOJUEGOS'], drop_first=True)
dummies.columns = ['CONSOLA_VIDEOJUEGOS']
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
print(df_nuevo[['CONSOLA_VIDEOJUEGOS', 'PUNT_GLOBAL']].corr())

## Data test

dummies_test = pd.get_dummies(df_test['FAMI_TIENECONSOLAVIDEOJUEGOS'], drop_first=True)
dummies_test.columns = ['CONSOLA_VIDEOJUEGOS']
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
#                      CONSOLA_VIDEOJUEGOS  PUNT_GLOBAL
# CONSOLA_VIDEOJUEGOS               1.0000       0.1398
# PUNT_GLOBAL                       0.1398       1.0000

# %%
plt.scatter(df_nuevo['CONSOLA_VIDEOJUEGOS'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre CONSOLA_VIDEOJUEGOS y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
dummies = pd.get_dummies(df_train['ESTU_HORASSEMANATRABAJA'], drop_first=True)
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
df = pd.concat([df_train, dummies], axis=1)
print(df[dummies.columns].corrwith(df['PUNT_GLOBAL']))

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_HORASSEMANATRABAJA'], drop_first=True)
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
# Entre 11 y 20 horas   -0.017382
# Entre 21 y 30 horas   -0.024759
# Menos de 10 horas     -0.012972
# Más de 30 horas       -0.047126
# dtype: float64

# %%
dummies = pd.get_dummies(df_train['ESTU_PAGOMATRICULA'], drop_first=True)
df_nuevo = pd.concat([df_nuevo, dummies], axis=1)
df = pd.concat([df_train, dummies], axis=1)
print(df[dummies.columns].corrwith(df['PUNT_GLOBAL']))

## Data test

dummies_test = pd.get_dummies(df_test['ESTU_PAGOMATRICULA'], drop_first=True)
df_nuevo_test = pd.concat([df_nuevo_test, dummies_test], axis=1)
# Out:
# Becas o Subsidios    0.065554
# Creditos            -0.107903
# Familiares           0.107739
# dtype: float64

# %%
#Se aplica media, o puede ser moda, mediana, depende del sesgo, debido a que hay valores NAN y deben tener info, valores que no recibe a la hora del entrenamiento
df_train['ESTU_INSE_INDIVIDUAL'] = df_train['ESTU_INSE_INDIVIDUAL'].fillna(df_train['ESTU_INSE_INDIVIDUAL'].mean())
df_nuevo = pd.concat([df_nuevo, df_train['ESTU_INSE_INDIVIDUAL']], axis=1).astype('float64')
print(df_nuevo[['ESTU_INSE_INDIVIDUAL', 'PUNT_GLOBAL']].corr())


## Data test

df_test['ESTU_INSE_INDIVIDUAL'] = df_test['ESTU_INSE_INDIVIDUAL'].fillna(df_test['ESTU_INSE_INDIVIDUAL'].mean())
df_nuevo_test = pd.concat([df_nuevo_test, df_test['ESTU_INSE_INDIVIDUAL']], axis=1).astype('float64')
# Out:
#                       ESTU_INSE_INDIVIDUAL  PUNT_GLOBAL
# ESTU_INSE_INDIVIDUAL              1.000000     0.238292
# PUNT_GLOBAL                       0.238292     1.000000

# %%
plt.scatter(df_nuevo['ESTU_INSE_INDIVIDUAL'], df_nuevo['PUNT_GLOBAL'], alpha=0.5)

# Etiquetas y título
plt.title('Relación entre ESTU_INSE_INDIVIDUAL y Puntaje Global')
plt.ylabel('PUNT_GLOBAL')

# Mostrar la gráfica
plt.show()

# %%
Columnas_no_Relevantes = [
    "ESTU_TIPODOCUMENTO", "ESTU_NACIONALIDAD","PERIODO","ESTU_CONSECUTIVO","ESTU_ESTUDIANTE","ESTU_PAIS_RESIDE",
    "ESTU_DEPTO_RESIDE","ESTU_MCPIO_RESIDE","ESTU_ESTADOCIVIL","ESTU_TIPODOCUMENTOSB11","FAMI_EDUCACIONPADRE","FAMI_EDUCACIONMADRE",
    "FAMI_OCUPACIONPADRE","FAMI_OCUPACIONMADRE","FAMI_TRABAJOLABORPADRE","FAMI_TRABAJOLABORMADRE","FAMI_CUANTOSCOMPARTEBAÑO",
    "ESTU_PRESENTACIONCASA","ESTU_PRESENTACIONSABADO","INST_NOMBRE_INSTITUCION","ESTU_PRGM_ACADEMICO","GRUPOREFERENCIA",
    "ESTU_PRGM_MUNICIPIO","ESTU_PRGM_DEPARTAMENTO","ESTU_NIVEL_PRGM_ACADEMICO","ESTU_NUCLEO_PREGRADO","ESTU_NUCLEO_PREGRADO_1",
    "ESTU_INST_MUNICIPIO","ESTU_INST_DEPARTAMENTO","INST_CARACTER_ACADEMICO","INST_ORIGEN","ESTU_MCPIO_PRESENTACION",
    "ESTU_DEPTO_PRESENTACION","ESTU_ESTADOINVESTIGACION", "ESTU_COD_RESIDE_DEPTO", "ESTU_COD_RESIDE_MCPIO","INST_COD_INSTITUCION",
    "ESTU_SNIES_PRGMACADEMICO","ESTU_PRGM_CODMUNICIPIO","ESTU_INST_CODMUNICIPIO","ESTU_COD_MCPIO_PRESENTACION","ESTU_COD_DEPTO_PRESENTACION"
]

df_train = df_train_raw.drop(columns = Columnas_no_Relevantes)
df_train
# Out:
#        ESTU_GENERO ESTU_FECHANACIMIENTO ESTU_EXTERIOR     ESTU_AREARESIDE  \
# 0                M           12/12/2000            NO  Cabecera Municipal
# 1                M           21/07/2001            NO  Cabecera Municipal
# 2                F           21/04/1997            NO  Cabecera Municipal
# 3                F           20/07/1995            NO  Cabecera Municipal
# 4                F           02/06/1978            NO  Cabecera Municipal
# ...            ...                  ...           ...                 ...
# 111425           F           08/02/2001            NO  Cabecera Municipal
# 111426           F           06/10/2000            NO  Cabecera Municipal
# 111427           M           10/01/1965            NO  Cabecera Municipal
# 111428           F           14/11/2001            NO  Cabecera Municipal
# 111429           M           09/10/1998            NO  Cabecera Municipal
#
#        ESTU_TITULOOBTENIDOBACHILLER            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0               Bachiller académico         Entre 500 mil y menos de 1 millón
# 1               Bachiller académico    Entre 1 millón y menos de 2.5 millones
# 2               Bachiller académico    Entre 1 millón y menos de 2.5 millones
# 3               Bachiller académico                         No pagó matrícula
# 4               Bachiller académico  Entre 2.5 millones y menos de 4 millones
# ...                             ...                                       ...
# 111425            Bachiller técnico                         No pagó matrícula
# 111426          Bachiller académico  Entre 4 millones y menos de 5.5 millones
# 111427          Bachiller académico  Entre 2.5 millones y menos de 4 millones
# 111428          Bachiller académico  Entre 4 millones y menos de 5.5 millones
# 111429            Bachiller técnico    Entre 1 millón y menos de 2.5 millones
#
#        ESTU_PAGOMATRICULABECA ESTU_PAGOMATRICULACREDITO  \
# 0                          Si                        No
# 1                          Si                        No
# 2                          Si                        No
# 3                          Si                        No
# 4                          No                        No
# ...                       ...                       ...
# 111425                     Si                        No
# 111426                     Si                        No
# 111427                     No                        No
# 111428                     No                        Si
# 111429                     No                        No
#
#        ESTU_PAGOMATRICULAPADRES ESTU_PAGOMATRICULAPROPIO  ...  \
# 0                            No                       No  ...
# 1                            No                       No  ...
# 2                            No                       No  ...
# 3                            Si                       No  ...
# 4                            No                       Si  ...
# ...                         ...                      ...  ...
# 111425                       Si                       No  ...
# 111426                       Si                       No  ...
# 111427                       No                       Si  ...
# 111428                       No                       No  ...
# 111429                       No                       Si  ...
#
#        FAMI_TIENECONSOLAVIDEOJUEGOS ESTU_HORASSEMANATRABAJA  \
# 0                                No     Entre 11 y 20 horas
# 1                                Si     Entre 11 y 20 horas
# 2                                No       Menos de 10 horas
# 3                                No                       0
# 4                                No         Más de 30 horas
# ...                             ...                     ...
# 111425                          NaN                     NaN
# 111426                           No         Más de 30 horas
# 111427                           No         Más de 30 horas
# 111428                           No     Entre 11 y 20 horas
# 111429                           Si         Más de 30 horas
#
#        ESTU_PAGOMATRICULA              ESTU_VLRULTIMOSEMESCURSADO  \
# 0              Familiares                  Menos de 500 mil pesos
# 1       Becas o Subsidios                  Menos de 500 mil pesos
# 2       Becas o Subsidios                  Menos de 500 mil pesos
# 3       Becas o Subsidios                        No pago semestre
# 4                 Propios                    Entre 3 y 5 millones
# ...                   ...                                     ...
# 111425                NaN                                     NaN
# 111426         Familiares                    Entre 3 y 5 millones
# 111427           Creditos  Entre un millon y 3 millones de pesose
# 111428           Creditos                    Entre 3 y 5 millones
# 111429            Propios  Entre un millon y 3 millones de pesose
#
#         ESTU_METODO_PRGM ESTU_PRIVADO_LIBERTAD PUNT_GLOBAL  \
# 0             PRESENCIAL                     N         188
# 1              DISTANCIA                     N         140
# 2              DISTANCIA                     N         140
# 3             PRESENCIAL                     N         111
# 4       DISTANCIA VITUAL                     N         135
# ...                  ...                   ...         ...
# 111425        PRESENCIAL                     N         137
# 111426        PRESENCIAL                     N         161
# 111427        PRESENCIAL                     N         124
# 111428        PRESENCIAL                     N         142
# 111429         DISTANCIA                     N         148
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL ESTU_NSE_IES
# 0                 55.570156                 3.0            2
# 1                 38.105883                 1.0            2
# 2                 65.658631                 4.0            2
# 3                 49.260729                 2.0            2
# 4                 55.138843                 2.0            3
# ...                     ...                 ...          ...
# 111425                  NaN                 NaN            2
# 111426            63.619372                 4.0            3
# 111427            48.648902                 2.0            2
# 111428            52.877602                 2.0            4
# 111429            47.195704                 2.0            2
#
# [111430 rows x 36 columns]

# %% [markdown]
# **1.2. Existen nulos?, ¿cómo se deben imputar?**

# %% [markdown]
# Si existen valores nulos y se deben imputar con la media, moda o mediana, dependiendo del sesgo que exista se puede utilizar una o la otra en mi caso se utilizo la media

# %%
columnas_continuas = ["ESTU_INSE_INDIVIDUAL","ESTU_NSE_INDIVIDUAL", "ESTU_NSE_IES"]
columnas_categoricas = [col for col in df_train.columns if (col not in columnas_continuas) and (col != "PUNT_GLOBAL")]

def RellenarNull(data):
    new_data = data.copy()
    mean = new_data[columnas_continuas].mean()
    mode = new_data[columnas_categoricas].mode()

    # Llenar nulos con la media para variables numéricas
    for col in new_data[columnas_continuas]:
        for i, val in enumerate(new_data[col]):
            if math.isnan(val):
                new_data.loc[i, col] = mean[col]

    # Llenar nulos con la moda para variables categóricas
    new_data[columnas_categoricas] = new_data[columnas_categoricas].apply(lambda x: x.fillna(x.value_counts().index[0]))

    return new_data

df_train = RellenarNull(df_train)

for i, val in enumerate(df_train["PUNT_GLOBAL"]):
    if math.isnan(val):
        df_train.loc[i, col] = df_train["PUNT_GLOBAL"].mean()

# %% [markdown]
# **1.3. Crear dummy variables para incluirlas en la correlación**

# %%
def transformData(data):

    # Obtener edad actual de cada persona
    data["ESTU_FECHANACIMIENTO"] = pd.to_datetime(data["ESTU_FECHANACIMIENTO"], format="mixed", dayfirst=True, errors='coerce')
    today = pd.to_datetime('today', format="%d/%m/%Y")
    data["ESTU_FECHANACIMIENTO"] = data["ESTU_FECHANACIMIENTO"].apply(lambda x: today.year - x.year - ((today.month, today.day) < (x.month, x.day)))
    age_mean = data["ESTU_FECHANACIMIENTO"].mean()

    for i, val in enumerate(data["ESTU_FECHANACIMIENTO"]):
        if str(val) == 'nan':
            data.loc[i, "ESTU_FECHANACIMIENTO"] = age_mean

    # Trasnformar valores binomiales

    # Genero (M: 0, F: 1)
    data["ESTU_GENERO"] = data["ESTU_GENERO"].apply(lambda x: 1 if x == 'F' else 0)

    # Estudia en el exterior (NO: False, SI: True)
    data["ESTU_EXTERIOR"] = data["ESTU_EXTERIOR"].apply(lambda x: x == 'SI')

    # Área de residencia (Area Rural: 0, Cabecera Municipal: 1)
    data["ESTU_AREARESIDE"] = data["ESTU_AREARESIDE"].apply(lambda x: 1 if x == 'Cabecera Municipal' else 0)

    # Pago con beca
    data["ESTU_PAGOMATRICULABECA"] = data["ESTU_PAGOMATRICULABECA"].apply(lambda x: x == 'Si')
    # Pago con crédito
    data["ESTU_PAGOMATRICULACREDITO"] = data["ESTU_PAGOMATRICULACREDITO"].apply(lambda x: x == 'Si')
    # Pago con padres
    data["ESTU_PAGOMATRICULAPADRES"] = data["ESTU_PAGOMATRICULAPADRES"].apply(lambda x: x == 'Si')
    # Pago propio
    data["ESTU_PAGOMATRICULAPROPIO"] = data["ESTU_PAGOMATRICULAPROPIO"].apply(lambda x: x == 'Si')

    # Hizo simulacro
    data["ESTU_SIMULACROTIPOICFES"] = data["ESTU_SIMULACROTIPOICFES"].apply(lambda x: x == 'Si')
    # Hizo actividades de refuerzo en áreas
    data["ESTU_ACTIVIDADREFUERZOAREAS"] = data["ESTU_ACTIVIDADREFUERZOAREAS"].apply(lambda x: x == 'Si')
    # Hizo actividades de refuerzo genéricas
    data["ESTU_ACTIVIDADREFUERZOGENERIC"] = data["ESTU_ACTIVIDADREFUERZOGENERIC"].apply(lambda x: x == 'Si')

    # Tiene internet
    data["FAMI_TIENEINTERNET"] = data["FAMI_TIENEINTERNET"].apply(lambda x: x == 'Si')
    # Tiene computador
    data["FAMI_TIENECOMPUTADOR"] = data["FAMI_TIENECOMPUTADOR"].apply(lambda x: x == 'Si')
    # Tiene lavadora
    data["FAMI_TIENELAVADORA"] = data["FAMI_TIENELAVADORA"].apply(lambda x: x == 'Si')
    # Tiene microondas
    data["FAMI_TIENEHORNOMICROOGAS"] = data["FAMI_TIENEHORNOMICROOGAS"].apply(lambda x: x == 'Si')
    # Tiene TV
    data["FAMI_TIENESERVICIOTV"] = data["FAMI_TIENESERVICIOTV"].apply(lambda x: x == 'Si')
    # Tiene automovil
    data["FAMI_TIENEAUTOMOVIL"] = data["FAMI_TIENEAUTOMOVIL"].apply(lambda x: x == 'Si')
    # Tiene motocicleta
    data["FAMI_TIENEMOTOCICLETA"] = data["FAMI_TIENEMOTOCICLETA"].apply(lambda x: x == 'Si')
    # Tiene consola de videojuegos
    data["FAMI_TIENECONSOLAVIDEOJUEGOS"] = data["FAMI_TIENECONSOLAVIDEOJUEGOS"].apply(lambda x: x == 'Si')

    # Método del programa (PRESENCIAL: 0 DISTANCIA VITUAL: 1)
    data["ESTU_METODO_PRGM"] = data["ESTU_METODO_PRGM"].apply(lambda x: 1 if x == 'DISTANCIA VITUAL' else 0)

    # Privado de libertad
    data["ESTU_PRIVADO_LIBERTAD"] = data["ESTU_PRIVADO_LIBERTAD"].apply(lambda x: x == 'S')

transformData(df_train)
print("Nulos: ", np.where(pd.isnull(df_train)))
df_train
# Out:
# Nulos:  (array([], dtype=int64), array([], dtype=int64))
#         ESTU_GENERO  ESTU_FECHANACIMIENTO  ESTU_EXTERIOR  ESTU_AREARESIDE  \
# 0                 0                  24.0          False                1
# 1                 0                  23.0          False                1
# 2                 1                  28.0          False                1
# 3                 1                  29.0          False                1
# 4                 1                  46.0          False                1
# ...             ...                   ...            ...              ...
# 111425            1                  24.0          False                1
# 111426            1                  24.0          False                1
# 111427            0                  60.0          False                1
# 111428            1                  23.0          False                1
# 111429            0                  26.0          False                1
#
#        ESTU_TITULOOBTENIDOBACHILLER            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0               Bachiller académico         Entre 500 mil y menos de 1 millón
# 1               Bachiller académico    Entre 1 millón y menos de 2.5 millones
# 2               Bachiller académico    Entre 1 millón y menos de 2.5 millones
# 3               Bachiller académico                         No pagó matrícula
# 4               Bachiller académico  Entre 2.5 millones y menos de 4 millones
# ...                             ...                                       ...
# 111425            Bachiller técnico                         No pagó matrícula
# 111426          Bachiller académico  Entre 4 millones y menos de 5.5 millones
# 111427          Bachiller académico  Entre 2.5 millones y menos de 4 millones
# 111428          Bachiller académico  Entre 4 millones y menos de 5.5 millones
# 111429            Bachiller técnico    Entre 1 millón y menos de 2.5 millones
#
#         ESTU_PAGOMATRICULABECA  ESTU_PAGOMATRICULACREDITO  \
# 0                         True                      False
# 1                         True                      False
# 2                         True                      False
# 3                         True                      False
# 4                        False                      False
# ...                        ...                        ...
# 111425                    True                      False
# 111426                    True                      False
# 111427                   False                      False
# 111428                   False                       True
# 111429                   False                      False
#
#         ESTU_PAGOMATRICULAPADRES  ESTU_PAGOMATRICULAPROPIO  ...  \
# 0                          False                     False  ...
# 1                          False                     False  ...
# 2                          False                     False  ...
# 3                           True                     False  ...
# 4                          False                      True  ...
# ...                          ...                       ...  ...
# 111425                      True                     False  ...
# 111426                      True                     False  ...
# 111427                     False                      True  ...
# 111428                     False                     False  ...
# 111429                     False                      True  ...
#
#        FAMI_TIENECONSOLAVIDEOJUEGOS ESTU_HORASSEMANATRABAJA  \
# 0                             False     Entre 11 y 20 horas
# 1                              True     Entre 11 y 20 horas
# 2                             False       Menos de 10 horas
# 3                             False                       0
# 4                             False         Más de 30 horas
# ...                             ...                     ...
# 111425                        False         Más de 30 horas
# 111426                        False         Más de 30 horas
# 111427                        False         Más de 30 horas
# 111428                        False     Entre 11 y 20 horas
# 111429                         True         Más de 30 horas
#
#        ESTU_PAGOMATRICULA              ESTU_VLRULTIMOSEMESCURSADO  \
# 0              Familiares                  Menos de 500 mil pesos
# 1       Becas o Subsidios                  Menos de 500 mil pesos
# 2       Becas o Subsidios                  Menos de 500 mil pesos
# 3       Becas o Subsidios                        No pago semestre
# 4                 Propios                    Entre 3 y 5 millones
# ...                   ...                                     ...
# 111425         Familiares  Entre un millon y 3 millones de pesose
# 111426         Familiares                    Entre 3 y 5 millones
# 111427           Creditos  Entre un millon y 3 millones de pesose
# 111428           Creditos                    Entre 3 y 5 millones
# 111429            Propios  Entre un millon y 3 millones de pesose
#
#         ESTU_METODO_PRGM  ESTU_PRIVADO_LIBERTAD  PUNT_GLOBAL  \
# 0                      0                  False          188
# 1                      0                  False          140
# 2                      0                  False          140
# 3                      0                  False          111
# 4                      1                  False          135
# ...                  ...                    ...          ...
# 111425                 0                  False          137
# 111426                 0                  False          161
# 111427                 0                  False          124
# 111428                 0                  False          142
# 111429                 0                  False          148
#
#        ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  ESTU_NSE_IES
# 0                 55.570156            3.000000             2
# 1                 38.105883            1.000000             2
# 2                 65.658631            4.000000             2
# 3                 49.260729            2.000000             2
# 4                 55.138843            2.000000             3
# ...                     ...                 ...           ...
# 111425            55.028124            2.678834             2
# 111426            63.619372            4.000000             3
# 111427            48.648902            2.000000             2
# 111428            52.877602            2.000000             4
# 111429            47.195704            2.000000             2
#
# [111430 rows x 36 columns]

# %%
def normalizar(data):
    for i, col in enumerate(data.columns):
        data[col] = 0 if data[col].std() == 0 else (data[col] - data[col].mean()) / data[col].std()

# Crear dummies
df_train_dummies = pd.get_dummies(df_train)
normalizar(df_train_dummies)
df_train_dummies
# Out:
#         ESTU_GENERO  ESTU_FECHANACIMIENTO  ESTU_EXTERIOR  ESTU_AREARESIDE  \
# 0         -1.141938             -0.706290      -0.123835          0.37177
# 1         -1.141938             -0.849843      -0.123835          0.37177
# 2          0.875696             -0.132078      -0.123835          0.37177
# 3          0.875696              0.011475      -0.123835          0.37177
# 4          0.875696              2.451874      -0.123835          0.37177
# ...             ...                   ...            ...              ...
# 111425     0.875696             -0.706290      -0.123835          0.37177
# 111426     0.875696             -0.706290      -0.123835          0.37177
# 111427    -1.141938              4.461615      -0.123835          0.37177
# 111428     0.875696             -0.849843      -0.123835          0.37177
# 111429    -1.141938             -0.419184      -0.123835          0.37177
#
#         ESTU_PAGOMATRICULABECA  ESTU_PAGOMATRICULACREDITO  \
# 0                     1.534565                  -0.617858
# 1                     1.534565                  -0.617858
# 2                     1.534565                  -0.617858
# 3                     1.534565                  -0.617858
# 4                    -0.651645                  -0.617858
# ...                        ...                        ...
# 111425                1.534565                  -0.617858
# 111426                1.534565                  -0.617858
# 111427               -0.651645                  -0.617858
# 111428               -0.651645                   1.618480
# 111429               -0.651645                  -0.617858
#
#         ESTU_PAGOMATRICULAPADRES  ESTU_PAGOMATRICULAPROPIO  \
# 0                      -0.834938                 -0.942998
# 1                      -0.834938                 -0.942998
# 2                      -0.834938                 -0.942998
# 3                       1.197683                 -0.942998
# 4                      -0.834938                  1.060439
# ...                          ...                       ...
# 111425                  1.197683                 -0.942998
# 111426                  1.197683                 -0.942998
# 111427                 -0.834938                  1.060439
# 111428                 -0.834938                 -0.942998
# 111429                 -0.834938                  1.060439
#
#         ESTU_SIMULACROTIPOICFES  ESTU_ACTIVIDADREFUERZOAREAS  ...  \
# 0                      0.075645                     0.098651  ...
# 1                      0.075645                     0.098651  ...
# 2                      0.075645                     0.098651  ...
# 3                      0.075645                     0.098651  ...
# 4                      0.075645                     0.098651  ...
# ...                         ...                          ...  ...
# 111425                 0.075645                     0.098651  ...
# 111426                 0.075645                     0.098651  ...
# 111427                 0.075645                     0.098651  ...
# 111428                 0.075645                     0.098651  ...
# 111429                 0.075645                     0.098651  ...
#
#         ESTU_PAGOMATRICULA_Becas o Subsidios  ESTU_PAGOMATRICULA_Creditos  \
# 0                                  -0.507153                    -0.547684
# 1                                   1.971773                    -0.547684
# 2                                   1.971773                    -0.547684
# 3                                   1.971773                    -0.547684
# 4                                  -0.507153                    -0.547684
# ...                                      ...                          ...
# 111425                             -0.507153                    -0.547684
# 111426                             -0.507153                    -0.547684
# 111427                             -0.507153                     1.825854
# 111428                             -0.507153                     1.825854
# 111429                             -0.507153                    -0.547684
#
#         ESTU_PAGOMATRICULA_Familiares  \
# 0                            1.485369
# 1                           -0.673227
# 2                           -0.673227
# 3                           -0.673227
# 4                           -0.673227
# ...                               ...
# 111425                       1.485369
# 111426                       1.485369
# 111427                      -0.673227
# 111428                      -0.673227
# 111429                      -0.673227
#
#         ESTU_VLRULTIMOSEMESCURSADO_Entre 3 y 5 millones  \
# 0                                             -0.456533
# 1                                             -0.456533
# 2                                             -0.456533
# 3                                             -0.456533
# 4                                              2.190403
# ...                                                 ...
# 111425                                        -0.456533
# 111426                                         2.190403
# 111427                                        -0.456533
# 111428                                         2.190403
# 111429                                        -0.456533
#
#         ESTU_VLRULTIMOSEMESCURSADO_Entre 5 y 7 millones  \
# 0                                             -0.273497
# 1                                             -0.273497
# 2                                             -0.273497
# 3                                             -0.273497
# 4                                             -0.273497
# ...                                                 ...
# 111425                                        -0.273497
# 111426                                        -0.273497
# 111427                                        -0.273497
# 111428                                        -0.273497
# 111429                                        -0.273497
#
#         ESTU_VLRULTIMOSEMESCURSADO_Entre 500 mil y un millon de pesos  \
# 0                                               -0.239647
# 1                                               -0.239647
# 2                                               -0.239647
# 3                                               -0.239647
# 4                                               -0.239647
# ...                                                   ...
# 111425                                          -0.239647
# 111426                                          -0.239647
# 111427                                          -0.239647
# 111428                                          -0.239647
# 111429                                          -0.239647
#
#         ESTU_VLRULTIMOSEMESCURSADO_Entre un millon y 3 millones de pesose  \
# 0                                               -0.704445
# 1                                               -0.704445
# 2                                               -0.704445
# 3                                               -0.704445
# 4                                               -0.704445
# ...                                                   ...
# 111425                                           1.419545
# 111426                                          -0.704445
# 111427                                           1.419545
# 111428                                          -0.704445
# 111429                                           1.419545
#
#         ESTU_VLRULTIMOSEMESCURSADO_Mas de 7 millones  \
# 0                                          -0.276743
# 1                                          -0.276743
# 2                                          -0.276743
# 3                                          -0.276743
# 4                                          -0.276743
# ...                                              ...
# 111425                                     -0.276743
# 111426                                     -0.276743
# 111427                                     -0.276743
# 111428                                     -0.276743
# 111429                                     -0.276743
#
#         ESTU_VLRULTIMOSEMESCURSADO_Menos de 500 mil pesos  \
# 0                                                2.582217
# 1                                                2.582217
# 2                                                2.582217
# 3                                               -0.387261
# 4                                               -0.387261
# ...                                                   ...
# 111425                                          -0.387261
# 111426                                          -0.387261
# 111427                                          -0.387261
# 111428                                          -0.387261
# 111429                                          -0.387261
#
#         ESTU_VLRULTIMOSEMESCURSADO_No pago semestre
# 0                                         -0.453214
# 1                                         -0.453214
# 2                                         -0.453214
# 3                                          2.206445
# 4                                         -0.453214
# ...                                             ...
# 111425                                    -0.453214
# 111426                                    -0.453214
# 111427                                    -0.453214
# 111428                                    -0.453214
# 111429                                    -0.453214
#
# [111430 rows x 83 columns]

# %% [markdown]
# **1.4. Crear una correlación, que variables tienen un efecto positivo en el puntaje y
# cuales un efecto negativo.**

# %%
df_train_dummies.corrwith(df_train_dummies["PUNT_GLOBAL"]).sort_values(ascending=False).iloc[1:]
# Out:
# ESTU_NSE_IES                                                             0.262818
# ESTU_VALORMATRICULAUNIVERSIDAD_Más de 7 millones                         0.244534
# ESTU_INSE_INDIVIDUAL                                                     0.238292
# ESTU_NSE_INDIVIDUAL                                                      0.215721
# ESTU_VLRULTIMOSEMESCURSADO_Mas de 7 millones                             0.213380
#                                                                            ...
# ESTU_VALORMATRICULAUNIVERSIDAD_Entre 1 millón y menos de 2.5 millones   -0.144575
# FAMI_ESTRATOVIVIENDA_Estrato 1                                          -0.160728
# ESTU_PAGOMATRICULAPROPIO                                                -0.165790
# ESTU_VLRULTIMOSEMESCURSADO_Entre un millon y 3 millones de pesose       -0.185439
# ESTU_FECHANACIMIENTO                                                    -0.252665
# Length: 82, dtype: float64

# %% [markdown]
# **Al realizar la correlación de cada variable contra PUNT_GLOBAL, se pueden observar las variables que tienen un efecto positivo en la parte superior; y las que tienen un efecto negativo en la parte inferior. El nivel socioeconómico es la variable que más influencia en el puntaje global.**

# %% [markdown]
# **2. Divida los datos en training y testing**

# %%
x, y = df_train_dummies[[col for col in df_train_dummies.columns if col != "PUNT_GLOBAL"]], df_train["PUNT_GLOBAL"]
xr, xs, yr, ys = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# **2.2. Entrenar un modelos de regresión**

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
model = LinearRegression()

model.fit(xr, yr)
# Out:
# LinearRegression()

# %% [markdown]
# **2.3. ¿Cuál es el mejor R squared? Cuál es el MAPE y el MSE.**

# %%
yr_hat = model.predict(xr)

def getR2(true, pred):
    SSR, SST = sum((true-pred)**2), sum((true-np.mean(true))**2)
    R2 = 1 - (float(SSR))/SST
    return R2

def getMSE(true, pred):
    return (1/len(true))*sum((true-pred)**2)

def getMAPE(true, pred):
    return (100/len(true)*sum(abs(pred-true)/true))

print("Training:")
print("R²   ", getR2(yr, yr_hat))
print("MAPE ", getMAPE(yr, yr_hat), "(Hay puntajes en 0)")
print("MSE  ", getMSE(yr, yr_hat))
# Out:
# Training:
# R²    0.24921568326717902
# MAPE  inf (Hay puntajes en 0)
# MSE   412.40981270961294

# %% [markdown]
# **4. Utilizando los datos de test medir el MAPE y el MSE de test. Qué tan diferentes son las
# métricas de training. (El menor error del grupo tiene un +1)**

# %%
ys_hat = model.predict(xs)

print("Test:")
print("R²   ", getR2(ys, ys_hat))
print("MAPE ", getMAPE(ys, ys_hat), "(Hay puntajes en 0)")
print("MSE  ", getMSE(ys, ys_hat))
# Out:
# Test:
# R²    0.2548432731321364
# MAPE  inf (Hay puntajes en 0)
# MSE   412.665406539113

# %% [markdown]
# **5. Describa en palabras que dice el modelo cuales son los principales hallazgos.**

# %%
df_test_raw = pd.read_csv("test_pruebas.csv", low_memory=False)
df_test = df_test_raw.drop(columns=Columnas_no_Relevantes)
df_test = RellenarNull(df_test)
transformData(df_test)
df_test_dummies = pd.get_dummies(df_test)
normalizar(df_test_dummies)
df_test_dummies
# Out:
#        ESTU_GENERO  ESTU_FECHANACIMIENTO  ESTU_EXTERIOR  ESTU_AREARESIDE  \
# 0         0.873960              3.006981      -0.122216         0.362459
# 1        -1.144175             -0.422352      -0.122216         0.362459
# 2         0.873960             -0.279464      -0.122216         0.362459
# 3         0.873960              0.292092      -0.122216         0.362459
# 4         0.873960              0.292092       8.181928         0.362459
# ...            ...                   ...            ...              ...
# 27853     0.873960              0.577870      -0.122216         0.362459
# 27854    -1.144175             -0.708130      -0.122216         0.362459
# 27855     0.873960              3.435648      -0.122216         0.362459
# 27856     0.873960             -0.136575      -0.122216         0.362459
# 27857     0.873960             -0.851019      -0.122216        -2.758834
#
#        ESTU_PAGOMATRICULABECA  ESTU_PAGOMATRICULACREDITO  \
# 0                   -0.653165                   1.643914
# 1                    1.530951                  -0.608282
# 2                   -0.653165                  -0.608282
# 3                   -0.653165                  -0.608282
# 4                   -0.653165                  -0.608282
# ...                       ...                        ...
# 27853               -0.653165                   1.643914
# 27854               -0.653165                   1.643914
# 27855                1.530951                  -0.608282
# 27856               -0.653165                  -0.608282
# 27857               -0.653165                  -0.608282
#
#        ESTU_PAGOMATRICULAPADRES  ESTU_PAGOMATRICULAPROPIO  \
# 0                     -0.833058                 -0.946695
# 1                     -0.833058                 -0.946695
# 2                     -0.833058                 -0.946695
# 3                      1.200354                 -0.946695
# 4                     -0.833058                 -0.946695
# ...                         ...                       ...
# 27853                 -0.833058                  1.056269
# 27854                  1.200354                 -0.946695
# 27855                 -0.833058                 -0.946695
# 27856                  1.200354                  1.056269
# 27857                  1.200354                  1.056269
#
#        ESTU_SIMULACROTIPOICFES  ESTU_ACTIVIDADREFUERZOAREAS  ...  \
# 0                     0.075763                      0.09706  ...
# 1                     0.075763                      0.09706  ...
# 2                     0.075763                      0.09706  ...
# 3                     0.075763                      0.09706  ...
# 4                     0.075763                      0.09706  ...
# ...                        ...                          ...  ...
# 27853                 0.075763                      0.09706  ...
# 27854                 0.075763                      0.09706  ...
# 27855                 0.075763                      0.09706  ...
# 27856                 0.075763                      0.09706  ...
# 27857                 0.075763                      0.09706  ...
#
#        ESTU_PAGOMATRICULA_Becas o Subsidios  ESTU_PAGOMATRICULA_Creditos  \
# 0                                 -0.508133                     1.853608
# 1                                 -0.508133                     1.853608
# 2                                  1.967917                    -0.539469
# 3                                 -0.508133                    -0.539469
# 4                                 -0.508133                    -0.539469
# ...                                     ...                          ...
# 27853                             -0.508133                    -0.539469
# 27854                             -0.508133                    -0.539469
# 27855                             -0.508133                     1.853608
# 27856                             -0.508133                    -0.539469
# 27857                              1.967917                    -0.539469
#
#        ESTU_PAGOMATRICULA_Familiares  \
# 0                          -0.675279
# 1                          -0.675279
# 2                          -0.675279
# 3                           1.480816
# 4                           1.480816
# ...                              ...
# 27853                      -0.675279
# 27854                      -0.675279
# 27855                      -0.675279
# 27856                      -0.675279
# 27857                      -0.675279
#
#        ESTU_VLRULTIMOSEMESCURSADO_Entre 3 y 5 millones  \
# 0                                            -0.454813
# 1                                            -0.454813
# 2                                            -0.454813
# 3                                            -0.454813
# 4                                            -0.454813
# ...                                                ...
# 27853                                        -0.454813
# 27854                                         2.198627
# 27855                                        -0.454813
# 27856                                        -0.454813
# 27857                                        -0.454813
#
#        ESTU_VLRULTIMOSEMESCURSADO_Entre 5 y 7 millones  \
# 0                                            -0.269317
# 1                                             3.712968
# 2                                            -0.269317
# 3                                            -0.269317
# 4                                            -0.269317
# ...                                                ...
# 27853                                        -0.269317
# 27854                                        -0.269317
# 27855                                        -0.269317
# 27856                                        -0.269317
# 27857                                        -0.269317
#
#        ESTU_VLRULTIMOSEMESCURSADO_Entre 500 mil y un millon de pesos  \
# 0                                              -0.245202
# 1                                              -0.245202
# 2                                              -0.245202
# 3                                              -0.245202
# 4                                              -0.245202
# ...                                                  ...
# 27853                                          -0.245202
# 27854                                          -0.245202
# 27855                                          -0.245202
# 27856                                          -0.245202
# 27857                                          -0.245202
#
#        ESTU_VLRULTIMOSEMESCURSADO_Entre un millon y 3 millones de pesose  \
# 0                                               1.425919
# 1                                              -0.701277
# 2                                              -0.701277
# 3                                               1.425919
# 4                                               1.425919
# ...                                                  ...
# 27853                                           1.425919
# 27854                                          -0.701277
# 27855                                          -0.701277
# 27856                                           1.425919
# 27857                                           1.425919
#
#        ESTU_VLRULTIMOSEMESCURSADO_Mas de 7 millones  \
# 0                                         -0.275324
# 1                                         -0.275324
# 2                                         -0.275324
# 3                                         -0.275324
# 4                                         -0.275324
# ...                                             ...
# 27853                                     -0.275324
# 27854                                     -0.275324
# 27855                                     -0.275324
# 27856                                     -0.275324
# 27857                                     -0.275324
#
#        ESTU_VLRULTIMOSEMESCURSADO_Menos de 500 mil pesos  \
# 0                                              -0.391896
# 1                                              -0.391896
# 2                                              -0.391896
# 3                                              -0.391896
# 4                                              -0.391896
# ...                                                  ...
# 27853                                          -0.391896
# 27854                                          -0.391896
# 27855                                           2.551605
# 27856                                          -0.391896
# 27857                                          -0.391896
#
#        ESTU_VLRULTIMOSEMESCURSADO_No pago semestre
# 0                                        -0.454123
# 1                                        -0.454123
# 2                                         2.201967
# 3                                        -0.454123
# 4                                        -0.454123
# ...                                            ...
# 27853                                    -0.454123
# 27854                                    -0.454123
# 27855                                    -0.454123
# 27856                                    -0.454123
# 27857                                    -0.454123
#
# [27858 rows x 82 columns]

# %%
df_test_pred = model.predict(df_test_dummies)
output = pd.DataFrame(df_test_pred, columns=["GLOBAL_SCORE"])


with open("Regression.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["id","GLOBAL_SCORE"])
    for i, val in enumerate(np.array(output["GLOBAL_SCORE"])):
        writer.writerow([df_test_raw["ESTU_CONSECUTIVO"][i],val])

# %% [markdown]
# **KNN**

# %%
x, y = df_train_dummies[[col for col in df_train_dummies.columns if col != "PUNT_GLOBAL"]], df_train["PUNT_GLOBAL"]
xr, xs, yr, ys = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
neightbor_sizes = [5,10,20,30]

for s in neightbor_sizes:
    knn = KNeighborsRegressor(n_neighbors=s)
    knn.fit(xr, yr)
    yr_hat = knn.predict(xr)
    print(f"{s} vecinos:")
    print("MSE(train)   ", getMSE(yr, yr_hat))
    print("MAPE(train)  ", getMAPE(yr, yr_hat))

    ys_hat = knn.predict(xs)
    print("MSE(test)    ", getMSE(ys, ys_hat))
    print("MAPE(test)   ", getMAPE(ys, ys_hat))

    print("---------------------------------")
# Out:
# 5 vecinos:
# MSE(train)    324.52614376738626
# MAPE(train)   inf
# MSE(test)     487.55602979449174
# MAPE(test)    inf
# ---------------------------------
# 10 vecinos:
# MSE(train)    367.6690562460753
# MAPE(train)   inf
# MSE(test)     449.46068069640205
# MAPE(test)    inf
# ---------------------------------
# 20 vecinos:
# MSE(train)    391.4619576752275
# MAPE(train)   inf
# MSE(test)     434.0411608184527
# MAPE(test)    inf
# ---------------------------------
# 30 vecinos:
# MSE(train)    400.53373571597444
# MAPE(train)   inf
# MSE(test)     428.544228314733
# MAPE(test)    inf
# ---------------------------------
